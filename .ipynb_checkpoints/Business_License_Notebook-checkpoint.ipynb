# %% [markdown]
# # Analysis of Calgary Business License Data
#
# Dataset provided by: The City of Calgary

# %%
import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import data.
df = pd.read_csv('Calgary_Business_Licences.csv')
df.head()
# Out:
#                             TRADENAME            ADDRESS  \
# 0              MORE CONVENIENCE STORE     11201 30 ST SW
# 1                               CUBEX  9304 HORTON RD SW
# 2  RESTAURANT AT LOUGHEED HOUSE (THE)       707 13 AV SW
# 3           WESTECK WINDOWS AND DOORS   #4 2015 32 AV NE
# 4                  ARBOUR LAKE LIQUOR  37 CROWFOOT RI NW
#
#                           LICENCETYPES      COMDISTNM     JOBSTATUSDESC  \
# 0             RETAIL DEALER - PREMISES      CEDARBRAE  RENEWAL LICENSED
# 1                           WHOLESALER       HAYSBORO  RENEWAL LICENSED
# 2  ALCOHOL BEVERAGE SALES (RESTAURANT)       BELTLINE  RENEWAL LICENSED
# 3             RETAIL DEALER - PREMISES  SOUTH AIRWAYS  RENEWAL LICENSED
# 4                         LIQUOR STORE    ARBOUR LAKE  RENEWAL LICENSED
#
#    JOBCREATED   longitude   latitude                               location  \
# 0  2009/06/11 -114.130062  50.953449  (50.9534492575157, -114.130062103058)
# ...

# %%
# Describe the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30660 entries, 0 to 30659
# Data columns (total 10 columns):
# TRADENAME        30660 non-null object
# ADDRESS          30660 non-null object
# LICENCETYPES     30660 non-null object
# COMDISTNM        30660 non-null object
# JOBSTATUSDESC    30660 non-null object
# JOBCREATED       30660 non-null object
# longitude        30660 non-null float64
# latitude         30660 non-null float64
# location         30660 non-null object
# Count            30660 non-null int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Geographical Distribution of Data (using plotly)

# %%
# import geopandas and import the shapefile (.shp)
import geopandas as gpd
map_df = gpd.read_file('Calgary_Community_Boundaries/geo_export_98191e70-c41b-4550-8551-d9977b2f1bde.shp')
map_df.head()
# Out:
#                class  class_code comm_code    comm_struc          name  \
# 0        Residential         1.0       SNA    INNER CITY       SUNALTA
# 1        Residential         1.0       WSP  BUILDING OUT  WEST SPRINGS
# 2  Residual Sub Area         4.0       12A         OTHER           12A
# 3        Residential         1.0       WND         1950s  WINDSOR PARK
# 4        Residential         1.0       WAL  BUILDING OUT        WALDEN
#
#       sector         srg                                           geometry
# 0     CENTRE   BUILT-OUT  POLYGON ((-114.10061493005 51.047994301993, -1...
# 1       WEST  DEVELOPING  POLYGON ((-114.187805990867 51.061506344418, -...
# 2  SOUTHEAST         N/A  POLYGON ((-113.869446537594 50.979572332142, -...
# 3     CENTRE   BUILT-OUT  POLYGON ((-114.081517547811 51.008716296692, -...
# 4      SOUTH  DEVELOPING  POLYGON ((-114.01032391161 50.868149357409, -1...

# %%
map_df['srg'].unique()
# Out:
# array([u'BUILT-OUT', u'DEVELOPING', u'N/A'], dtype=object)

# %%
map_df['comm_struc'].unique()
# Out:
# array([u'INNER CITY', u'BUILDING OUT', u'OTHER', u'1950s', u'2000s',
#        u'EMPLOYMENT', u'1960s/1970s', u'1980s/1990s', u'UNDEVELOPED',
#        u'CENTRE CITY', u'PARKS', None], dtype=object)

# %%
map_df['class'].unique()
# Out:
# array([u'Residential', u'Residual Sub Area', u'Industrial', u'Major Park'], dtype=object)

# %%
# Plot 4 maps in a quadrant:
    # Plot 1) By sector  (Centre, West, South, etc.)
    # Plot 2) By class (Residential, Residual Sub Area, Industrial, Major Park)
    # Plot 3) By 'srg' (Built Out, Developing, N/A)
    # Plot 4) By 'comm_struc' or community structure

# Plot map.
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=[15,15])
# Plot 1
map_df.plot(column = 'sector', ax = axes[0,0], legend = True, legend_kwds = {'loc':3,'fontsize':8}, title = 'Calgary by Sectors')
# Plot 2
map_df.plot(column = 'class', ax = axes[0,1], legend = True, legend_kwds = {'loc':3,'fontsize':8},cmap='Set3')
# Plot 2
map_df.plot(column = 'class', ax = axes[0,1], legend = True, legend_kwds = {'loc':3,'fontsize':8},cmap='Set3')



# Turn off the axes.
for ax_ in axes:
    for ax in ax_:
        ax.axis('off')

# %%
iplot(choromap)
# Out:
# <div id="b793bdf3-ff6f-4182-a5da-63687ef3a122" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b793bdf3-ff6f-4182-a5da-63687ef3a122", [{"colorscale": "Greens", "text": ["text1", "text2", "text3"], "locations": ["AZ", "PA", "NY"], "colorbar": {"title": "Colourbar Title"}, "locationmode": "USA-states", "z": [1.0, 2.0, 3.0], "type": "choropleth"}], {"geo": {"scope": "usa"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
import plotly.plotly as py
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)

data = dict(type='choropleth',locations = ['AZ','PA','NY'],\
            locationmode= 'USA-states', colorscale = 'Greens', \
            text = ['text1','text2','text3'],\
            z = [1.0,2.0,3.0],\
            colorbar = {'title':'Colourbar Title'})
        
layout = dict(geo = {'scope':'usa'})
choromap = go.Figure(data = [data], layout = layout)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
